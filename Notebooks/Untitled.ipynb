# %%
A = readdlm("ceilometro_2015-01-17.dat")
# Out:
# 144×5 Array{Any,2}:
#   0   0  0  2070.0      ""
#   0  10  0  2070.0      ""
#   0  20  0  2060.0      ""
#   0  30  0  2050.0      ""
#   0  40  0  2040.0  2040.0
#   0  50  0  2030.0  2030.0
#   1   0  0  2020.0  2020.0
#   1  10  0  1900.0  1900.0
#   1  20  0  1900.0  1900.0
#   1  30  0  1990.0  1990.0
#   1  40  0  1980.0  1980.0
#   1  50  0  1870.0  1870.0
#   2   0  0  1880.0  1880.0
#   ⋮
#  22   0  0  2440.0  2440.0
#  22  10  0  2420.0  2420.0
#  22  20  0  2400.0  2400.0
#  22  30  0  1830.0  1830.0
#  22  40  0  1810.0  1810.0
#  22  50  0  1800.0  1800.0
#  23   0  0  1800.0  1800.0
#  23  10  0  1820.0  1820.0
#  23  20  0   840.0   840.0
#  23  30  0  1985.0  1985.0
#  23  40  0  1980.0  1980.0
#  23  50  0  1980.0  1980.0

# %%
# Out:
# SubString{String}

# %%
A[:, 1] = A[:, 1] + A[:,2]/60
# Out:
# 144-element Array{Float64,1}:
#   0.0
#   0.166667
#   0.333333
#   0.5
#   0.666667
#   0.833333
#   1.0
#   1.16667
#   1.33333
#   1.5
#   1.66667
#   1.83333
#   2.0
#   ⋮
#  22.0
#  22.1667
#  22.3333
#  22.5
#  22.6667
#  22.8333
#  23.0
#  23.1667
#  23.3333
#  23.5
#  23.6667
#  23.8333

# %%
A[:,1]
# Out:
# 144-element Array{Any,1}:
#   0.0
#   0.166667
#   0.333333
#   0.5
#   0.666667
#   0.833333
#   1.0
#   1.16667
#   1.33333
#   1.5
#   1.66667
#   1.83333
#   2.0
#   ⋮
#  22.0
#  22.1667
#  22.3333
#  22.5
#  22.6667
#  22.8333
#  23.0
#  23.1667
#  23.3333
#  23.5
#  23.6667
#  23.8333

# %%
using PyPlot

# %%
plot(A[:,1], A[:, 4])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x12304bc90>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x12d84e510>
